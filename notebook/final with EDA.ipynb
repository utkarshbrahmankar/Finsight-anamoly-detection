# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import roc_auc_score, average_precision_score, precision_score, recall_score, f1_score
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# #### Connecting to Cloud Database

# %%
engine = create_engine('postgresql://username:password@anomaly-detection-anomaly-detection.a.aivencloud.com:18261/database_name?sslmode=require')

# %%
# df = pd.read_sql('anomaly', engine)
df = pd.read_csv('new_input.csv')
df_copy = df.copy()

# %%
df
# Out:
#         step transaction_id      type      amount     nameOrig  oldbalanceOrg  \
# 0          1   AF6516654475  TRANSFER      181.00  C1305486145         181.00
# 1          1   TI7248945902   PAYMENT     5746.44   C845388562           0.00
# 2          1   ND2949797655   PAYMENT     5607.36   C948424584        5202.00
# 3          1   AL8844588271   PAYMENT     6360.79  C2027701910        3731.00
# 4          1   AL2384499094   CASH_IN    67200.07  C1448277333      108912.00
# ...      ...            ...       ...         ...          ...            ...
# 636257   743   AW6555590893  CASH_OUT   339682.13   C786484425      339682.13
# 636258   743   NL5044497097  TRANSFER  6311409.28  C1529008245     6311409.28
# 636259   743   LG9651474524  CASH_OUT  6311409.28  C1162922333     6311409.28
# 636260   743   VC6892232416  TRANSFER   850002.52  C1685995037      850002.52
# 636261   743   ZV1207395405  CASH_OUT   850002.52  C1280323807      850002.52
#
#         newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  \
# 0                 0.00   C553264065            0.00            0.00
# 1                 0.00   M550572371            0.00            0.00
# 2                 0.00  M1447685190            0.00            0.00
# 3                 0.00  M1345293143            0.00            0.00
# 4            176112.07   C243745864            0.00            0.00
# ...                ...          ...             ...             ...
# 636257            0.00   C776919290            0.00       339682.13
# 636258            0.00  C1881841831            0.00            0.00
# 636259            0.00  C1365125890        68488.84      6379898.11
# 636260            0.00  C2080388513            0.00            0.00
# 636261            0.00   C873221189      6510099.11      7360101.63
#
#             Country  isFraud
# 0           Zambia         1
# 1            Nepal         0
# 2         Bulgaria         0
# 3          Croatia         0
# 4        Macedonia         0
# ...             ...      ...
# 636257      Latvia         1
# 636258  Uzbekistan         1
# 636259    Malaysia         1
# 636260      Greece         1
# 636261    Slovakia         1
#
# [636262 rows x 12 columns]

# %% [markdown]
# #### Feature Engineering

# %%
df['hour_of_day'] = (df['step']) % 24
df['balance_change_orig'] = (df['newbalanceOrig'] - df['oldbalanceOrg']).abs()
df['balance_change_dest'] = (df['newbalanceDest'] - df['oldbalanceDest']).abs()
df["errorBalanceOrg"] = (df.newbalanceOrig + df.amount - df.oldbalanceOrg).abs()
df["errorBalanceDest"] = (df.oldbalanceDest + df.amount - df.newbalanceDest).abs()
df['transactionBetween'] = df['nameDest'].apply(lambda x: 'Customer2Customer' if x[0] == "C" else 'Customer2Merchant')

# %%
df_append=df[['type','transactionBetween']]

# %%
df = pd.get_dummies(df, columns=['type', 'transactionBetween'])

# %% [markdown]
# #### EDA

# %%
ax = df['isFraud'].value_counts().plot(kind='bar')
plt.xlabel('Transaction Type')
plt.xticks(ticks=[0,1], labels=['Non-Fraud','Fraud'], )
plt.ylabel('No. of observations (Millions)')
plt.title('No. of obervations in each class')
for i in ax.patches:
    ax.text(i.get_x()+0.1, i.get_height()+3, str(round(i.get_height(), 2)), fontsize=15, color='black')

plt.show()

# %%
plt.figure(figsize=(18,6))

ax = (df['hour_of_day'].value_counts(sort=False, normalize=True) * 100).round(2).plot(kind='bar')

for i in ax.patches:
    ax.text(i.get_x(), i.get_height(), str(round(i.get_height(), 2)) + "%", fontsize=12, color='black')
    
plt.xlabel('hour_of_day')
plt.ylabel('% of observations')
plt.title('No. of obervations at each hour')
plt.show()

# %%
plt.figure(figsize=(18,6))
sns.lineplot(data=df_copy.groupby(['step','type']).agg({'amount' : 'mean'}).round(2).reset_index(),
             x='step',
             y='amount',
             hue='type')
plt.xlabel('hour_of_day')
plt.ylabel('Avg. transaction amount (millions)')
plt.title('Avg. transaction amount at each hour')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2,1,sharex = True)
fig.suptitle("Average amount per class")
bins = 70
fraud_mask = df['isFraud']==1
ax1.hist(df.loc[fraud_mask, 'amount'], bins = bins)
ax1.set_title('Fraud Amount')

ax2.hist(df.loc[-fraud_mask, 'amount'], bins = bins)
ax2.set_title('Normal Amount')

plt.xlabel('amount')
plt.ylabel('# of Transactions')
plt.yscale('log')
plt.show()

# %% [markdown]
# #### Modelling

# %%
X = df[['step', 'amount', 'oldbalanceOrg', 'newbalanceDest', 'balance_change_orig', 'balance_change_dest', 'errorBalanceDest', 'type_CASH_OUT', 'type_TRANSFER', 'transactionBetween_Customer2Customer']]
y = df['isFraud']

# %%
X
# Out:
#         step      amount  oldbalanceOrg  newbalanceDest  balance_change_orig  \
# 0          1      181.00         181.00            0.00               181.00
# 1          1     5746.44           0.00            0.00                 0.00
# 2          1     5607.36        5202.00            0.00              5202.00
# 3          1     6360.79        3731.00            0.00              3731.00
# 4          1    67200.07      108912.00            0.00             67200.07
# ...      ...         ...            ...             ...                  ...
# 636257   743   339682.13      339682.13       339682.13            339682.13
# 636258   743  6311409.28     6311409.28            0.00           6311409.28
# 636259   743  6311409.28     6311409.28      6379898.11           6311409.28
# 636260   743   850002.52      850002.52            0.00            850002.52
# 636261   743   850002.52      850002.52      7360101.63            850002.52
#
#         balance_change_dest  errorBalanceDest  type_CASH_OUT  type_TRANSFER  \
# 0                      0.00      1.810000e+02          False           True
# 1                      0.00      5.746440e+03          False          False
# 2                      0.00      5.607360e+03          False          False
# 3                      0.00      6.360790e+03          False          False
# 4                      0.00      6.720007e+04          False          False
# ...                     ...               ...            ...            ...
# 636257            339682.13      0.000000e+00           True          False
# 636258                 0.00      6.311409e+06          False           True
# 636259           6311409.27      1.000000e-02           True          False
# 636260                 0.00      8.500025e+05          False           True
# 636261            850002.52      9.313226e-10           True          False
#
#         transactionBetween_Customer2Customer
# 0                                       True
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                       True
# ...                                      ...
# 636257                                  True
# 636258                                  True
# 636259                                  True
# 636260                                  True
# 636261                                  True
#
# [636262 rows x 10 columns]

# %%
from sklearn.ensemble import IsolationForest
X=X.rename(str,axis=1)
model = IsolationForest(random_state=42)
model.fit(X)
# Out:
# IsolationForest(random_state=42)

# %%
anomaly_scores = model.decision_function(X)
df['anomaly_score'] = anomaly_scores
outliers = model.predict(X)
restricted_countries = ['Syria ', 'Cuba ','Bulgaria ']
df['isRestrict'] = df['Country'].apply(lambda x: 1 if x in restricted_countries else 0)

df['outlier'] = outliers
df['outlier'] = df['outlier'].replace({-1: 1, 1: 0})

# %%
threshold = -0.28
plt.hist(df['anomaly_score'], bins=35)
plt.axvline(threshold, color='r')
plt.show()

# %%
total_outliers = (df['outlier']==1).sum()
print("Total number of outliers:", total_outliers)
# Out:
# Total number of outliers: 65632

# %%
df.loc[df['isRestrict']==1, 'Country'].value_counts()
# Out:
# Country
# Syria        3700
# Bulgaria     1715
# Cuba         1149
# Name: count, dtype: int64

# %%
binary_predictions = [1 if x == -1 else 0 for x in outliers]
y_true = df['isFraud'].values 

# Calculate evaluation metrics
auroc = roc_auc_score(y_true, binary_predictions)
auprc = average_precision_score(y_true, binary_predictions)
precision = precision_score(y_true, binary_predictions)
recall = recall_score(y_true, binary_predictions)
f1 = f1_score(y_true, binary_predictions)

print("AUROC:", auroc)
print("AUPRC:", auprc)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# AUROC: 0.9050093093186478
# AUPRC: 0.10322936032108708
# Precision: 0.11296318868844465
# Recall: 0.902715207597711
# F1 Score: 0.20079897081725237

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_true, binary_predictions)

# Calculate AUC score
auc_score = roc_auc_score(y_true, binary_predictions)
print("AUC Score:", auc_score)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % auc_score)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', lw=1)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# AUC Score: 0.9050093093186478

# %% [markdown]
# #### Sending Data to Cloud

# %%
df= pd.concat([df, df_append], axis=1)
df.drop(columns=['transactionBetween_Customer2Customer',
       'transactionBetween_Customer2Merchant', 
       'type_CASH_IN', 'type_CASH_OUT', 'type_DEBIT', 'type_PAYMENT',
       'type_TRANSFER'], inplace=True)
desired_column_order = ['step','hour_of_day', 'transaction_id','type', 'amount','transactionBetween', 'nameOrig', 'oldbalanceOrg',
       'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest',
       'isFraud',  'balance_change_orig', 'balance_change_dest',
       'errorBalanceOrg', 'errorBalanceDest', 'anomaly_score', 'outlier','Country','isRestrict']

df = df.reindex(columns=desired_column_order)

df.rename(columns={'oldbalanceOrg':'oldBalanceOrig', 'newbalanceOrig':'newBalanceOrig', 
                    'oldbalanceDest':'oldBalanceDest', 'newbalanceDest':'newBalanceDest', 'balance_change_dest': 'destChange',
                         'balance_change_orig':'origChange', 
                        'anomaly_score': 'iso_anomaly_score', 'outlier':'iso_outliers'}, inplace=True)

# %%
df
# Out:
#         step  hour_of_day transaction_id      type      amount  \
# 0          1            1   AF6516654475  TRANSFER      181.00
# 1          1            1   TI7248945902   PAYMENT     5746.44
# 2          1            1   ND2949797655   PAYMENT     5607.36
# 3          1            1   AL8844588271   PAYMENT     6360.79
# 4          1            1   AL2384499094   CASH_IN    67200.07
# ...      ...          ...            ...       ...         ...
# 636257   743           23   AW6555590893  CASH_OUT   339682.13
# 636258   743           23   NL5044497097  TRANSFER  6311409.28
# 636259   743           23   LG9651474524  CASH_OUT  6311409.28
# 636260   743           23   VC6892232416  TRANSFER   850002.52
# 636261   743           23   ZV1207395405  CASH_OUT   850002.52
#
#        transactionBetween     nameOrig  oldBalanceOrig  newBalanceOrig  \
# 0       Customer2Customer  C1305486145          181.00            0.00
# 1       Customer2Merchant   C845388562            0.00            0.00
# 2       Customer2Merchant   C948424584         5202.00            0.00
# 3       Customer2Merchant  C2027701910         3731.00            0.00
# 4       Customer2Customer  C1448277333       108912.00       176112.07
# ...                   ...          ...             ...             ...
# 636257  Customer2Customer   C786484425       339682.13            0.00
# 636258  Customer2Customer  C1529008245      6311409.28            0.00
# 636259  Customer2Customer  C1162922333      6311409.28            0.00
# 636260  Customer2Customer  C1685995037       850002.52            0.00
# 636261  Customer2Customer  C1280323807       850002.52            0.00
#
#            nameDest  ...  newBalanceDest  isFraud  origChange  destChange  \
# 0        C553264065  ...            0.00        1      181.00        0.00
# 1        M550572371  ...            0.00        0        0.00        0.00
# 2       M1447685190  ...            0.00        0     5202.00        0.00
# 3       M1345293143  ...            0.00        0     3731.00        0.00
# 4        C243745864  ...            0.00        0    67200.07        0.00
# ...             ...  ...             ...      ...         ...         ...
# 636257   C776919290  ...       339682.13        1   339682.13   339682.13
# 636258  C1881841831  ...            0.00        1  6311409.28        0.00
# 636259  C1365125890  ...      6379898.11        1  6311409.28  6311409.27
# 636260  C2080388513  ...            0.00        1   850002.52        0.00
# 636261   C873221189  ...      7360101.63        1   850002.52   850002.52
#
#         errorBalanceOrg  errorBalanceDest  iso_anomaly_score  iso_outliers  \
# 0                  0.00      1.810000e+02           0.029364             0
# 1               5746.44      5.746440e+03           0.101988             0
# 2                405.36      5.607360e+03           0.095730             0
# 3               2629.79      6.360790e+03           0.095321             0
# 4             134400.14      6.720007e+04           0.094537             0
# ...                 ...               ...                ...           ...
# 636257             0.00      0.000000e+00          -0.096878             1
# 636258             0.00      6.311409e+06          -0.303693             1
# 636259             0.00      1.000000e-02          -0.299784             1
# 636260             0.00      8.500025e+05          -0.211089             1
# 636261             0.00      9.313226e-10          -0.217503             1
#
#             Country isRestrict
# 0           Zambia           0
# 1            Nepal           0
# 2         Bulgaria           1
# 3          Croatia           0
# 4        Macedonia           0
# ...             ...        ...
# 636257      Latvia           0
# 636258  Uzbekistan           0
# 636259    Malaysia           0
# 636260      Greece           0
# 636261    Slovakia           0
#
# [636262 rows x 21 columns]

# %%
df.to_sql('new_output_1',engine,index=False,if_exists='replace')

# %% [markdown]
# #### Volume Anomaly Detection

# %%
df['nameOrig'].value_counts().head(3)
# Out:
# nameOrig
# C849745739    713
# C866529530    196
# C684230144    195
# Name: count, dtype: int64

# %%
cus_df = df.loc[df['nameOrig']=='C849745739']
cus_df.loc[cus_df['iso_outliers']==1].head()
# Out:
#     step  hour_of_day transaction_id      type      amount transactionBetween  \
# 29     1            1   VW6375111256  TRANSFER  2107293.71  Customer2Customer
# 30     1            1   RJ4733625034  TRANSFER  1918461.70  Customer2Customer
# 31     1            1   TA7700429649  TRANSFER   291753.70  Customer2Customer
# 32     1            1   GF4121254192  TRANSFER   556542.19  Customer2Customer
# 40     1            1   VL8653869379  TRANSFER    96757.40  Customer2Customer
#
#       nameOrig  oldBalanceOrig  newBalanceOrig     nameDest  ...  \
# 29  C849745739             0.0             0.0  C1816757085  ...
# 30  C849745739             0.0             0.0  C1782113663  ...
# 31  C849745739             0.0             0.0  C1816757085  ...
# 32  C849745739             0.0             0.0  C1721246982  ...
# 40  C849745739             0.0             0.0   C306206744  ...
#
#     newBalanceDest  isFraud  origChange  destChange  errorBalanceOrg  \
# 29     10681238.79        0         0.0  1820392.63       2107293.71
# 30      3997768.55        0         0.0  1507563.85       1918461.70
# 31     10681238.79        0         0.0   286901.09        291753.70
# 32      1114787.21        0         0.0    68324.58        556542.19
# 40      3554299.27        0         0.0   436976.06         96757.40
#
#     errorBalanceDest  iso_anomaly_score  iso_outliers          Country  \
# 29         286901.08          -0.134436             1         Burundi
# 30         410897.85          -0.102791             1  American Samoa
# 31         578654.79          -0.071771             1         Liberia
# 32         624866.77          -0.011054             1      Kazakhstan
# 40         340218.66          -0.000374             1       West Bank
#
#    isRestrict
# 29          0
# 30          0
# 31          0
# 32          0
# 40          0
#
# [5 rows x 21 columns]

# %%
print('standard deviation: ', cus_df.loc[cus_df['iso_outliers']==1, 'amount'].std())
# Out:
# standard deviation:  750152.1162488841

# %%
cus_df.loc[cus_df['iso_outliers']==0].head()
# Out:
#     step  hour_of_day transaction_id      type     amount transactionBetween  \
# 78     1            1   UP2050349032  CASH_OUT  607537.17  Customer2Customer
# 79     1            1   YK3755040772  CASH_OUT  254399.35  Customer2Customer
# 80     1            1   CK8806428668  CASH_OUT  427823.47  Customer2Customer
# 81     1            1   YF1378004691  CASH_OUT  173570.67  Customer2Customer
# 82     1            1   IS2636178018  CASH_OUT  476934.35  Customer2Customer
#
#       nameOrig  oldBalanceOrig  newBalanceOrig     nameDest  ...  \
# 78  C849745739             0.0             0.0  C1286084959  ...
# 79  C849745739             0.0             0.0  C1810132623  ...
# 80  C849745739             0.0             0.0  C2083562754  ...
# 81  C849745739             0.0             0.0  C1850180796  ...
# 82  C849745739             0.0             0.0    C22805895  ...
#
#     newBalanceDest  isFraud  origChange  destChange  errorBalanceOrg  \
# 78      2107778.11        0         0.0    17661.77        607537.17
# 79        97128.19        0         0.0   358735.45        254399.35
# 80      1186556.81        0         0.0   409010.64        427823.47
# 81      1268668.92        0         0.0   680227.29        173570.67
# 82       651524.92        0         0.0    95272.10        476934.35
#
#     errorBalanceDest  iso_anomaly_score  iso_outliers             Country  \
# 78         589875.40           0.010900             0           Zimbabwe
# 79         613134.80           0.077390             0  Wallis and Futuna
# 80          18812.83           0.081897             0     American Samoa
# 81         506656.62           0.072836             0            Ireland
# 82         381662.25           0.061294             0             Rwanda
#
#    isRestrict
# 78          0
# 79          0
# 80          0
# 81          0
# 82          0
#
# [5 rows x 21 columns]

# %%
print('standard deviation: ', cus_df.loc[cus_df['iso_outliers']==0, 'amount'].std())
# Out:
# standard deviation:  150103.02999204994
